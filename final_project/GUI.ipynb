# %%
import tkinter as tk
import pandas as pd
import numpy as np
from math import exp, ceil
import torch

# %%
# 前置作業
new_row = {'LN(總價)':0,
           '中正區':0,
           '大安區':0,
           '松山區':0,
           '南港區':0,
           '內湖區':0,
           '信義區':0,
           '中山區':0,
           '士林區':0,
           '文山區':0,
           '北投區':0,
           '大同區':0,
           '萬華區':0,
           '住宅區':0,
           '商業區':0,
           '住商混合區':0,
           '公寓':0,
           '華廈':0,
           '住宅大樓':0,
           'LN(建物面積)':0,
           '樓層':0,
           'LN(屋齡)':0,
           '台鐵_直距(公里)':0,
           '百貨_直距(公里)':0,
           '大專_直距(公里)':0,
           '捷運_路距(公里)':0,
           '公園_路距(公里)':0,
           '公車站_路距(公里)':0,
           '國小_路距(公里)':0,
           '國中_路距(公里)':0,
           '高中職_路距(公里)':0,
           '採光':0,
           '管理':0,
           '邊間':0,
           '裝潢':0,
           '景觀':0}


floor=[]
for i in range(1,40):
    floor.append(str(i))

school=[]
for i in range(1,6001):
    school.append(str(i))

distance=[]
main_station=[]
for i in range(1,7000):
    distance.append(str(i))
    main_station.append(str(i))

for i in range(7000, 11000):
    main_station.append(str(i))

house_area=[]
for i in range(6, 420):
    house_area.append(str(i))

house_age=[]
for i in range(1,66):
    house_age.append(str(i))

# %%
# GUI part
import tkinter as tk


# 建立主視窗
main = tk.Tk()
main.title('預測房價使用介面')

# 視窗大小 寬乘高
main.geometry('1000x670')
main.resizable(False,False)

# 背景顏色
main['bg']='skyblue'


# 置頂
main.attributes('-topmost',1)

# get text from user function
def user_input():
    
    data=pd.read_excel('16實證資料.xlsx', usecols='A:Y, AA:AG, AI:AJ, AN:AO')


    # data clean and transform 
    for d in data['樓層']:
        if type(d)!=int:
            data.drop(data.loc[data['樓層']==d].index, inplace=True)

    # receive data from user
    # # 區域、區域特性、房型、建物面積、樓層 
    text = variable.get()
    text2 = variable2.get()
    text3 = variable3.get()
    text4 = variable4.get()
    text5 = variable5.get()
    # 有無採光、有無管理、有無邊間、有無裝潢、有無景觀
    text6 = variable6.get()
    text7 = variable7.get()
    text8 = variable8.get()
    text9 = variable9.get()
    text10 = variable10.get()
    # 屋齡、台鐵直距、百貨直距、大專直距、捷運路距
    text11 = variable11.get()
    text12 = variable12.get()
    text13 = variable13.get()
    text14 = variable14.get()
    text15 = variable15.get()
    # 公園路距、公車站路距、國小路距、國中路距、高中職路距
    text16 = variable16.get()
    text17 = variable17.get()
    text18 = variable18.get()
    text19 = variable19.get()
    text20 = variable20.get()
    
    # minmaxScale log data transform
    new_row[text]=1
    new_row[text2]=1
    new_row[text3]=1
    new_row['LN(建物面積)']=np.log(int(text4))
    new_row['樓層']=int(text5)
    new_row['採光']=int(text6)
    new_row['管理']=int(text7)
    new_row['邊間']=int(text8)
    new_row['裝潢']=int(text9)
    new_row['景觀']=int(text10)
    new_row['屋齡']=np.log(int(text11))
    new_row['台鐵_直距(公里)']=int(text12)
    new_row['百貨_直距(公里)']=int(text13)
    new_row['大專_直距(公里)']=int(text14)
    new_row['捷運_路距(公里)']=int(text15)
    new_row['公園_路距(公里)']=int(text16)
    new_row['公車站_路距(公里)']=int(text17)
    new_row['國小_路距(公里)']=int(text18)
    new_row['國中_路距(公里)']=int(text19)
    new_row['高中職_路距(公里)']=int(text20)
    
    data = data.append(new_row, ignore_index=True)
    
    # reset
    new_row = {'LN(總價)':0,
           '中正區':0,
           '大安區':0,
           '松山區':0,
           '南港區':0,
           '內湖區':0,
           '信義區':0,
           '中山區':0,
           '士林區':0,
           '文山區':0,
           '北投區':0,
           '大同區':0,
           '萬華區':0,
           '住宅區':0,
           '商業區':0,
           '住商混合區':0,
           '公寓':0,
           '華廈':0,
           '住宅大樓':0,
           'LN(建物面積)':0,
           '樓層':0,
           'LN(屋齡)':0,
           '台鐵_直距(公里)':0,
           '百貨_直距(公里)':0,
           '大專_直距(公里)':0,
           '捷運_路距(公里)':0,
           '公園_路距(公里)':0,
           '公車站_路距(公里)':0,
           '國小_路距(公里)':0,
           '國中_路距(公里)':0,
           '高中職_路距(公里)':0,
           '採光':0,
           '管理':0,
           '邊間':0,
           '裝潢':0,
           '景觀':0}

    min_max_scaler = preprocessing.MinMaxScaler()

    data['台鐵_直距(公里)'] = min_max_scaler.fit_transform(np.array(data['台鐵_直距(公里)']).reshape(-1, 1))
    data['百貨_直距(公里)'] = min_max_scaler.fit_transform(np.array(data['百貨_直距(公里)']).reshape(-1, 1))
    data['大專_直距(公里)'] = min_max_scaler.fit_transform(np.array(data['大專_直距(公里)']).reshape(-1, 1))
    data['捷運_路距(公里)'] = min_max_scaler.fit_transform(np.array(data['捷運_路距(公里)']).reshape(-1, 1))
    data['公園_路距(公里)'] = min_max_scaler.fit_transform(np.array(data['公園_路距(公里)']).reshape(-1, 1))
    data['公車站_路距(公里)'] = min_max_scaler.fit_transform(np.array(data['公車站_路距(公里)']).reshape(-1, 1))
    data['國小_路距(公里)'] = min_max_scaler.fit_transform(np.array(data['國小_路距(公里)']).reshape(-1, 1))
    data['國中_路距(公里)'] = min_max_scaler.fit_transform(np.array(data['國中_路距(公里)']).reshape(-1, 1))
    data['高中職_路距(公里)'] = min_max_scaler.fit_transform(np.array(data['高中職_路距(公里)']).reshape(-1, 1))

    # torch model predict result
    feature=data.iloc[-1,1:]
    data.drop([-1])

    feature=torch.from_numpy(np.array(feature, dtype='float32'))

    model = torch.jit.load('model_final.pt')
    model.eval()

    pred_result = exp(model(feature))
    
    lb.config(text='預測房價約'+str(ceil(pred_result))+'萬元新台幣')

# set option menu
def display_selected():
    lb.config(text=variable.get())
    

tp_regions = ['中正區', '萬華區',  '松山區', '南港區', '內湖區', '中山區', '士林區','大安區','文山區','信義區','北投區','大同區']
community_type = ['住宅區','商業區','住商混合區']
apartment_type = ['公寓','華廈','住宅大樓']
# 採光 管理 邊間 裝潢 景觀 
yes_no =['有','無']



variable = tk.StringVar()
variable2 = tk.StringVar()
variable3 = tk.StringVar()
variable4 = tk.StringVar()
variable5 = tk.StringVar()
variable6 = tk.StringVar()
variable7 = tk.StringVar()
variable8 = tk.StringVar()
variable9 = tk.StringVar()
variable10 = tk.StringVar()
variable11 = tk.StringVar()
variable12 = tk.StringVar()
variable13 = tk.StringVar()
variable14 = tk.StringVar()
variable15 = tk.StringVar()
variable16 = tk.StringVar()
variable17 = tk.StringVar()
variable18 = tk.StringVar()
variable19 = tk.StringVar()
variable20 = tk.StringVar()

variable.set('請選擇區域')
variable2.set('請選擇區域特性')
variable3.set('請選擇房型')        
variable4.set('請選擇有無採光')

variable5.set('請選擇有無管理')
variable6.set('請選擇有無邊間')
variable7.set('請選擇有無裝潢')
variable8.set('請選擇有無景觀')
variable9.set('請選擇建物面積(坪)') 
variable10.set('請選擇樓層') 
variable11.set('請選擇屋齡') 

variable12.set('請選擇台鐵直距(公里)') 
variable13.set('請選擇百貨直距(公里)') 
variable14.set('請選擇大專直距(公里)') 
variable15.set('請選擇捷運路距(公里)') 
variable16.set('請選擇公園路距(公里)') 
variable17.set('請選擇公車站路距(公里)') 

variable18.set('請選擇國小路距(公里)') 
variable19.set('請選擇國中路距(公里)') 
variable20.set('請選擇高中職路距(公里)') 


# tp_region
dropDown1 = tk.OptionMenu(
    main,
    variable,
    *tp_regions,
    command=display_selected
)
# community_type
dropDown2 = tk.OptionMenu(
    main,
    variable2,
    *community_type,
    command=display_selected
)
#
dropDown3 = tk.OptionMenu(
    main,
    variable3,
    *apartment_type,
    command=display_selected
)
#
dropDown4 = tk.OptionMenu(
    main,
    variable4,
    *yes_no,
    command=display_selected
)

dropDown5 = tk.OptionMenu(
    main,
    variable5,
    *yes_no,
    command=display_selected
)
dropDown6 = tk.OptionMenu(
    main,
    variable6,
    *yes_no,
    command=display_selected
)
dropDown7 = tk.OptionMenu(
    main,
    variable7,
    *yes_no,
    command=display_selected
)
dropDown8 = tk.OptionMenu(
    main,
    variable8,
    *yes_no,
    command=display_selected
)
dropDown9 = tk.OptionMenu(
    main,
    variable9,
    *house_area,
    command=display_selected
)
dropDown10 = tk.OptionMenu(
    main,
    variable10,
    *floor,
    command=display_selected
)
dropDown11 = tk.OptionMenu(
    main,
    variable11,
    *house_age,
    command=display_selected
)
dropDown12 = tk.OptionMenu(
    main,
    variable12,
    *main_station,
    command=display_selected
)
dropDown13 = tk.OptionMenu(
    main,
    variable13,
    *distance,
    command=display_selected
)
dropDown14 = tk.OptionMenu(
    main,
    variable14,
    *distance,
    command=display_selected
)
dropDown15 = tk.OptionMenu(
    main,
    variable15,
    *distance,
    command=display_selected
)
dropDown16 = tk.OptionMenu(
    main,
    variable16,
    *distance,
    command=display_selected
)
dropDown17 = tk.OptionMenu(
    main,
    variable17,
    *distance,
    command=display_selected
)
dropDown18 = tk.OptionMenu(
    main,
    variable18,
    *school,
    command=display_selected
)
dropDown19 = tk.OptionMenu(
    main,
    variable19,
    *school,
    command=display_selected
)
dropDown20 = tk.OptionMenu(
    main,
    variable20,
    *school,
    command=display_selected
)

# 區域、區域特性、房型、建物面積、樓層  
lb_instruction = tk.Label(fg='black',bg='skyblue',text='區域')
lb_instruction.place(anchor=tk.CENTER, x=200, y=165)
lb_instruction2 = tk.Label(fg='black',bg='skyblue',text='區域特性')
lb_instruction2.place(anchor=tk.CENTER, x=350, y=165)
lb_instruction3 = tk.Label(fg='black',bg='skyblue',text='房型')
lb_instruction3.place(anchor=tk.CENTER, x=500, y=165)
lb_instruction9 = tk.Label(fg='black',bg='skyblue',text='建物面積')
lb_instruction9.place(anchor=tk.CENTER, x=650, y=165)
lb_instruction10 = tk.Label(fg='black',bg='skyblue',text='樓層')
lb_instruction10.place(anchor=tk.CENTER, x=800, y=165)

dropDown1.place(anchor=tk.CENTER, x=200, y=190)
dropDown2.place(anchor=tk.CENTER, x=350, y=190)
dropDown3.place(anchor=tk.CENTER, x=500, y=190)
dropDown9.place(anchor=tk.CENTER, x=650, y=190)
dropDown10.place(anchor=tk.CENTER, x=800, y=190)

# 有無採光、有無管理、有無邊間、有無裝潢、有無景觀
lb_instruction4 = tk.Label(fg='black',bg='skyblue',text='有無採光')
lb_instruction4.place(anchor=tk.CENTER, x=200, y=225)
lb_instruction5 = tk.Label(fg='black',bg='skyblue',text='有無管理')
lb_instruction5.place(anchor=tk.CENTER, x=350, y=225)
lb_instruction6 = tk.Label(fg='black',bg='skyblue',text='有無邊間')
lb_instruction6.place(anchor=tk.CENTER, x=500, y=225)
lb_instruction7 = tk.Label(fg='black',bg='skyblue',text='有無裝潢')
lb_instruction7.place(anchor=tk.CENTER, x=650, y=225)
lb_instruction8 = tk.Label(fg='black',bg='skyblue',text='有無景觀')
lb_instruction8.place(anchor=tk.CENTER, x=800, y=225)

dropDown4.place(anchor=tk.CENTER, x=200, y=250)
dropDown5.place(anchor=tk.CENTER, x=800, y=250)
dropDown6.place(anchor=tk.CENTER, x=350, y=250)
dropDown7.place(anchor=tk.CENTER, x=500, y=250)
dropDown8.place(anchor=tk.CENTER, x=650, y=250)

# 屋齡、台鐵直距、百貨直距、大專直距、捷運路距
lb_instruction11 = tk.Label(fg='black',bg='skyblue',text='屋齡')
lb_instruction11.place(anchor=tk.CENTER, x=90, y=285)
lb_instruction12 = tk.Label(fg='black',bg='skyblue',text='台鐵直距')
lb_instruction12.place(anchor=tk.CENTER, x=250, y=285)
lb_instruction13 = tk.Label(fg='black',bg='skyblue',text='百貨直距')
lb_instruction13.place(anchor=tk.CENTER, x=450, y=285)
lb_instruction14 = tk.Label(fg='black',bg='skyblue',text='大專直距')
lb_instruction14.place(anchor=tk.CENTER, x=650, y=285)
lb_instruction15 = tk.Label(fg='black',bg='skyblue',text='捷運路距')
lb_instruction15.place(anchor=tk.CENTER, x=850, y=285)

dropDown11.place(anchor=tk.CENTER, x=90, y=310)
dropDown12.place(anchor=tk.CENTER, x=250, y=310)
dropDown13.place(anchor=tk.CENTER, x=450, y=310)
dropDown14.place(anchor=tk.CENTER, x=650, y=310)
dropDown15.place(anchor=tk.CENTER, x=850, y=310)

# 公園路距、公車站路距、國小路距、國中路距、高中職路距
lb_instruction16 = tk.Label(fg='black',bg='skyblue',text='公園路距')
lb_instruction16.place(anchor=tk.CENTER, x=100, y=345)
lb_instruction17 = tk.Label(fg='black',bg='skyblue',text='公車站路距')
lb_instruction17.place(anchor=tk.CENTER, x=300, y=345)
lb_instruction18 = tk.Label(fg='black',bg='skyblue',text='國小路距')
lb_instruction18.place(anchor=tk.CENTER, x=500, y=345)
lb_instruction19 = tk.Label(fg='black',bg='skyblue',text='國中路距')
lb_instruction19.place(anchor=tk.CENTER, x=700, y=345)
lb_instruction20 = tk.Label(fg='black',bg='skyblue',text='高中職路距')
lb_instruction20.place(anchor=tk.CENTER, x=900, y=345)

dropDown16.place(anchor=tk.CENTER, x=100, y=370)
dropDown17.place(anchor=tk.CENTER, x=300, y=370)
dropDown18.place(anchor=tk.CENTER, x=500, y=370)
dropDown19.place(anchor=tk.CENTER, x=700, y=370)
dropDown20.place(anchor=tk.CENTER, x=900, y=370)


# label
lb = tk.Label(fg='black',bg='skyblue',text='')
lb.place(anchor=tk.CENTER, x=500, y=550)


# input entry (model prediction result shows here)
en = tk.Entry()

# button
btn = tk.Button(text='送出資訊', command=user_input)
btn.place(anchor=tk.CENTER, x=500, y=450)

# 常駐主畫面
main.mainloop()
